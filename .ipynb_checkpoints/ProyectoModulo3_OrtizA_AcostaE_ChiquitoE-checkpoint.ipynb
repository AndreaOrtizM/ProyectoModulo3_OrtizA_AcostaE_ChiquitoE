# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="http://www.power-eng.com/content/dam/Pennenergy/online-articles/2014/11/co2-emissions.jpg" width="300px" height="100px" />
#
# <font color = pink>
#
# # México contra el Cambio Climático: Emisiones Gases de Efecto Invernadero y Energía Renovable
#
# <font color = purple>
#
# ## 1. Objetivos
#
# <font color = blue>
#
# ### 1.1 Objetivo general
# <font color = black>
# > - Analizar la tendencia de las emisiones de Gases de Efecto Invernadero (GEI) y del porcentaje de la generación de energía eléctrica proveniente de fuentes renovables en México para determinar si se logrará una cifra cercana a las metas establecidas por el mismo país.
#
#
# <font color = blue>
#
# ### 1.2 Objetivos específicos
#
# <font color = black>
# > - Importar los datos del Banco Mundial de las emisiones de GEI en México para obtener la gráfica de los mismos, así como la cantidad de emisiones de la línea base (2000).
# > - Con los datos hacer el ajuste polinomial hasta el grado que sea conveniente, para encontrar el mejor.
# > - Realizar una predicción para determinar las emisiones en 2020 y 2050 y comparar lo obtenido con las metas de reducción de la Ley General de Cambio Climático.
# > - Repetir un proceso similar para la generación de Energía de fuentes Renovables y posteriormente hacer la comparativa con el objetivo establecido en la misma Ley al año 2024.

# %% [markdown]
# <font color = purple>
#
# ## 2. Introducción
#
# <font color = black>
#
# Desde principios del siglo XX, los científicos han venido observando un cambio en el clima que no puede atribuirse únicamente a alguna de las influencias “naturales” del pasado. Este cambio en el clima, también denominado calentamiento global, ha ocurrido más rápido que cualquier otro cambio climático del que se haya tenido constancia.
#
# La causa principal del calentamiento global es el aumento de la concentración de Gases de Efecto Invernadero (GEI) en la atmósfera que se ha producido desde la Revolución Industrial, a finales del siglo XVIII. Como consecuencia del aumento de los gases que absorben y emiten radiación térmica, se retiene más calor en la atmósfera y, por consiguiente, aumenta la temperatura media global de la superficie. El aumento de la temperatura también tiene otras repercusiones sobre el sistema climático. El conjunto de estas repercusiones se denomina cambio climático antropogénico (provocado por la acción del hombre).
#
# Los principales GEI son:
#
# * Dióxido de carbono (CO2)
# * Metano (CH4)
# * Óxido Nitroso (N2O)
# * Hidrofluorocarbonos (HFC)
# * Perfluorocarbonos (PFC)
# * Hexafluoruro de azufre (SF6)
# * Trifluoruro de nitrógeno (NF3)
#
# Cada uno de estos gases tiene una capacidad diferente de atrapar el calor en la atmósfera, también denominado “potencial de calentamiento global” (PMC), con lo obtienes el dióxido de carbono equivalente, el cual básicamente es la conversión que utiliza el PMC de otros GEI comparado con el PCM del más abundante, CO2, teniendo así una equivalencia y una unidad de medida común.
#
# Los siete gases mencionados anteriormente son los más importantes y que están regulados por el Protocolo de Kioto (derivado del Convención Marco de las Naciones Unidas sobre el Cambio Climático), el cual establece objetivos legalmente vinculantes para los países desarrollados a fin de que estos limiten o reduzcan sus emisiones de GEI. Fue aprobado en 1997 y entró en vigor en 2005. El vapor de agua es el gas de efecto invernadero más importante, pero, como el ser humano no produce una cantidad significativa del mismo, no tenemos control alguno sobre su concentración en la atmósfera. En consecuencia, no está regulado por el Protocolo.
#
# Dentro de la CMNUCC, y el subsiguiente Protocolo, México está considerado como país no Anexo I, lo cual implica que no tiene una meta 'obligatoria' de reducción de emisiones mas sí el comprimiso de hacer Informes periódicos y cooperar con lo que esté en sus posibilidades. Adicionalmente, cabe destacar que México es líder dentro de los no Anexo I, ya por poco era clasificado como Anexo I (países desarrollados).
#
# En  junio 2012 se promulga en nuestro país la Ley General del Cambio Climático, con una posterior actualización en 2015. De ahí se desprendieron otros instrumentos de política pública como la Estrategia Nacional y el Programa Especial enfocados al mismo asunto.
#
# Algunos de los objetivos de esta Ley son:
#
# > *Garantizar el derecho a un medio ambiente sano, regular las acciones para la mitigación y adaptación al cambio climático, fomentar la educación, investigación, desarrollo y transferencia de tecnología e innovación y difusión sobre el tema y Establecer la bases para la concertación con la sociedad.*
#
# Los principios de Política, de acuerdo con el artículo 26 de la LGCC, son:
#
# * Aprovechamiento sustentable
# * Corresponsabilidad
# * Precaución
# * Prevención
# * Patrones producción y consumo para transitar a economía de bajas emisiones en carbono
# * Integralidad y transversalidad, coordinación y cooperación
# * Participación ciudadana en toda fase instrumental
# * Responsabilidad ambiental
# * Uso de instrumentos económicos
# * Transparencia, acceso a la información y a la justicia.
#
# Además, la LGCC reconoce la importancia de las Energías Renovables en el tema. Mediante el fomento de las energías renovables, México ayuda a mitigar la emisión de GEI y, al mismo tiempo, contribuye a diversificar la generación de energía eléctrica, lo que conlleva una mejora en materia de seguridad energética en el país.

# %% [markdown]
# <font color = purple>
#
# ## 3. Desarrollo
#
# <font color = black>
#
# Se obtuvieron los datos de lo Indicadores del Banco Mundial, las emisiones de GEI (en kilotoneladas de dióxido de carbono equivalente o Gigagramos, kt CO2e) a lo largo de los años desde 1970 a 2012. Posteriormente se agregó el dato del 2013 obtenido del Inventario Nacional de Emisiones, el mismo que aparece en el Primer Informe Bienal de Actualización de México ante la CMNUCC.
#
# En adición, cabe destacar que la LGCC establece algunas metas para nuestro país. Para el año 2020, se tendrían que reducir las emisiones de GEI en un 30% respecto a las emitidas en el año 2000, mientras que en 2050 la reducción es del 50% en relación al mismo año base. De acuerdo a la base de datos, en el años 2000 las emisiones eran de 576489.52 kt CO2e.
#
# Esto, en cifras se traduce en que:
#
# > * Para 2020 se tienen que reducir 172,946.856 kt CO2e (30%) lo cual quiere decir que en ese años debería haber 403542.664 kt CO2e.
#
# > * Para el 2050, la reducción del 50% implica que las emisiones de ese año deben ser de 288244.76 kt CO2e
#
# Con el indicador ya mencionado se hará el ajuste de la curva correspondiente para posteriormente hacer la predicción y analizar, en  base a la tendencia de la gráfica, qué tan viable es el logro de las metas.
#
# Un procedimiento similar se realizó con el tema de las energías renovables. México está comprometido con el cumplimiento de las metas de mitigación y en la misma LGCC se estipula que el 35% de la generación eléctrica debe provenir de energías limpias para 2024
#
# El Banco Mundial tiene la información del porcentaje de la generación de electricidad que es energía renovable para después hacer la predicción a 2024 y hacer la comparativa con la meta.

# %% [markdown]
# <font color = purple>
#
# ## 4. Simulaciones y resultados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sympy as sym
from sympy import init_printing; init_printing(use_latex='mathjax')
import pyomo_utilities

# %%
#importando los datos y graficando
data_file = 'Emisiones_mexico.csv'
data = pd.read_csv(data_file, header = None)

# %%
x = data.iloc[:, 0].values
y = data.iloc[:, 1].values

plt.figure()
plt.plot(x,y)
plt.show()

# %%
n = 6 #grado del polinomio

# %%
beta = pyomo_utilities.curve_polyfit(x, y, n)
yhat = beta.dot(np.array([x**i for i in range(n+1)]))
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 7
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
#ajuste de la curva de datos
plt.figure(figsize = (8,6))
plt.plot(x, y, '*b', label = 'datos reales')
plt.plot(x, yhat, '-c', label = 'ajuste %i terminos'%n)
plt.legend(loc = 'best')
plt.xlabel('año')
plt.ylabel('Emisiones [kt CO2e]')
plt.show()

# %%
#ajuste con ridge
beta20_ridge = pyomo_utilities.curve_polyfit(x, y, n, reg_mode = 'ridge', reg_coef = 1)
yhat20_ridge = np.array([x**i for i in range(n+1)]).T.dot(beta20_ridge)
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 7
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat, '-c', label = 'ajuste %i'%n)
plt.plot(x, yhat20_ridge, '--r', label = 'ajuste %i ridge'%n)
plt.legend(loc = 'best')
plt.xlabel('año')
plt.ylabel('Emisiones [kt CO2e]')
plt.grid()
plt.show()

# %% [markdown]
# Haciendo la proyección hasta 2050  para analizar los puntnos 2020 y 2050

# %%
xf = np.arange(1970, 2051, dtype="int64")
yf_ridge = np.array([xf**i for i in range(n+1)]).T.dot(beta20_ridge)
yf = beta.dot(np.array([xf**i for i in range(n+1)]))

plt.figure(figsize=(8,6))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(xf, yf, '-c', label = 'ajuste %i'%n)
plt.plot(xf, yf_ridge, '--r', label = 'ajuste %i ridge'%n)
plt.plot(2020,403542.664, '*g', label = 'meta 2020')
plt.plot(2050,288244.76, '*m', label = 'meta 2050')
plt.legend(loc = 'best')
plt.xlabel('año')
plt.ylabel('Emisiones [kt CO2e]')
plt.grid()
plt.show()

# %% [markdown]
# Examinando el indicador de Energias renovables en México y el mundo con ajuste grado 5

# %%
n= 5 #grado del ajuste

# %%
ren_file = 'renovables_mex.csv'
data_ren = pd.read_csv(ren_file, header = None)

# %%
#energías renovables en México y el mundo
x_ren = data_ren.iloc[0, :].values
mex_ren = data_ren.iloc[1, :].values
wor_ren = data_ren.iloc[2, :].values

beta_ren_mex = pyomo_utilities.curve_polyfit(x_ren, mex_ren, n)
beta20_ridge_ren_mex = pyomo_utilities.curve_polyfit(x_ren, mex_ren, n, reg_mode = 'ridge', reg_coef = 1)

mex_ridge_ren = np.array([x_ren**i for i in range(n+1)]).T.dot(beta20_ridge_ren_mex)
mex_ren_f = beta_ren_mex.dot(np.array([x_ren**i for i in range(n+1)]))

beta_ren_wor = pyomo_utilities.curve_polyfit(x_ren, wor_ren, n)
beta20_ridge_ren_wor = pyomo_utilities.curve_polyfit(x_ren, wor_ren, n, reg_mode = 'ridge', reg_coef = 1)


wor_ridge_ren = np.array([x_ren**i for i in range(n+1)]).T.dot(beta20_ridge_ren_wor)
wor_ren_f = beta_ren_wor.dot(np.array([x_ren**i for i in range(n+1)]))

plt.figure(figsize=(8,6))

plt.plot(x_ren, mex_ren, '*b', label = 'México')
plt.plot(x_ren, mex_ren_f, '-b', label = 'ajuste %i'%n)
plt.plot(x_ren, mex_ridge_ren, '--b', label = 'ajuste %i ridge'%n)

plt.plot(x_ren, wor_ren, '*r', label = "Mundo")
plt.plot(x_ren, wor_ren_f, '-r', label = 'ajuste %i'%n)
plt.plot(x_ren, wor_ridge_ren, '--r', label = 'ajuste %i ridge'%n)

plt.legend(loc = 'best')
plt.xlabel('$Año$')
plt.ylabel('$Porcentaje$')
plt.grid()
plt.show()
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 6
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %% [markdown]
# Porcentaje de energía hidroelectrica

# %%
hydro_file = 'hydro_mex.csv'
data_hydro = pd.read_csv(hydro_file, header = None)

# %%
x_hydro = data_hydro.iloc[0, :].values
mex_hydro = data_hydro.iloc[1, :].values
wor_hydro = data_hydro.iloc[2, :].values
plt.figure(figsize=(8,6))
plt.plot(x_hydro, mex_hydro, '-c', label = "México")
plt.plot(x_hydro, wor_hydro, '--r', label = "Mundo")
plt.legend(loc = 'best')
plt.xlabel('$Año$')
plt.ylabel('$Porcentaje$')
plt.grid()
plt.show()

# %% [markdown]
# Porcentaje de energía nuclear

# %%
nuc_file = 'nuclear_mex.csv'
data_nuc = pd.read_csv(nuc_file, header = None)

# %%
x_nuc = data_nuc.iloc[0, :].values
mex_nuc = data_nuc.iloc[1, :].values
wor_nuc = data_nuc.iloc[2, :].values
plt.figure(figsize=(8,6))
plt.plot(x_nuc, mex_nuc, '-c', label = "México")
plt.plot(x_nuc, wor_nuc, '--r', label = "Mundo")
plt.legend(loc = 'best')
plt.xlabel('$Año$')
plt.ylabel('$Porcentaje$')
plt.grid()
plt.show()

# %% [markdown]
# Energías renovables no hidroelectricas

# %%
rennh_file = 'rennh_mex.csv'
data_rennh = pd.read_csv(rennh_file, header = None)

# %%
x_rennh = data_rennh.iloc[0, :].values
mex_rennh = data_rennh.iloc[1, :].values
plt.figure(figsize=(8,6))
plt.plot(x_rennh, mex_rennh, '-c', label = "México")
plt.legend(loc = 'best')
plt.xlabel('año')
plt.ylabel('KWh')
plt.grid()
plt.show()

# %% [markdown]
# Proyección de energías renovables en México al 2050

# %%
xf_ren = np.arange(1990, 2050, dtype="int64")
mexf_ridge_ren = np.array([xf_ren**i for i in range(n+1)]).T.dot(beta20_ridge_ren_mex)
mexf_ren = beta_ren_mex.dot(np.array([xf_ren**i for i in range(n+1)]))

plt.figure(figsize=(8,6))
plt.plot(x_ren, mex_ren, '*b', label = 'datos')
plt.plot(xf_ren, mexf_ren, '-c', label = 'ajuste %i'%n)
plt.plot(xf_ren, mexf_ridge_ren, '--r', label = 'ajuste %i ridge'%n)
plt.plot(2024,35, '*g', label = 'meta 2024')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %% [markdown]
# <font color = purple>
#
# ## 5. Conclusiones
#
# <font color = black>
#
# * El calentamiento global es un problema grave que debe ser atendido y tratado con la seriedad correspondiente.
# * Los análisis muestran que estamos en un punto de inflexión en el cual si no se continúa con las medidas y se implementan correctamente las regulaciones, la tendencia puede ser catastrófica; si no es el caso, podríamos tener una mejora significativa.
# * Entre las limitaciones del modelo se encuentra que hay puntos que deberían tener un mayor peso ya que su variación no es aleatoria, sino producto de las recientes regulaciones.
# * De acuerdo con los objetivos específicos, se siguió la metodología para lograr analizar las tendencias y proyecciones correspondientes.

# %% [markdown]
# <font color = purple>
#
# ## 6. Referencias
#
# <font color = black>
#
# * Cámara de Diputados del H. Congreso de la Unión (2012). “Ley General de cambio Climático” [en línea]. Recuperado el 28 de noviembre del 2017 de: http://www.inecc.gob.mx/descargas/2012_lgcc.pdf
#
# * The World Bank. (s.f.). “Total greenhouse gas emissions (kt of CO2 equivalent)”. Recuperado el 28 de noviembre del 2017 de: https://data.worldbank.org/indicator/EN.ATM.GHGT.KT.CE?view=chart
#
# * Instituto Nacional de Ecología y Cambio Climático (INECC) y Secretaría de Medio Ambiente y Recursos Naturales (SEMARNAT). (2015). “Primer Informe Bienal de Actualización ante la Convención Marco de las Naciones Unidas sobre el Cambio Climático.” [en línea]. INECC/SEMARNAT, México. Recuperado el 28 de noviembre del 2017 de: http://unfccc.int/files/national_reports/non-annex_i_parties/biennial_update_reports/application/pdf/mexbur1.pdf
#
# * UNCC:Learn (2017). "Introducción al Cambio Climático: Módulo 1 y 2". [curso en línea].
#
# * Cordero, C. (2017). "En fomento a energías renovables, SHCP debe informar beneficios fiscales." [en línea].Agencia Quadratín. Recuperado el 30 de noviembre del 2017 de: https://mexico.quadratin.com.mx/fomento-energias-renovables-shcp-informar-beneficios-fiscales/
#
# * The World Bank. (s.f.). "Renewable electricity output (% of total electricity output)." Recuperado el 30 de noviembre del 2017 de: https://data.worldbank.org/indicator/EG.ELC.RNEW.ZS?view=chart
#
# * The World Bank. (s.f.). Indicators. Recuperado el 30 de noviembre del 2017 de: https://data.worldbank.org/indicator

# %% [markdown]
# Github: https://github.com/AndreaOrtizM/ProyectoModulo3_OrtizA_AcostaE_ChiquitoE
